# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# # Observation of the Weather analysis
#
#
# After reviewing the date, I have made 3 key observations.
# * 	We can see that there is a higher concentration of cities with higher humidity from 50 to 70 degrees.
# * 	The highest temperatures can be seen at latitudes from 10 to 25 degrees.
# * 	Wind speeds average below 20 MPH, but the going north of 40 degrees and south of -40 degrees we can see increasing in the wind speeds.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Create URL to get the weather info from the Weather API
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# Create empty lists for API data
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the counter 
record = 1

# Log file print statement
print(f"Retreiving Weather data for below cities")
print(f"----------------------------------------")

#Loop through the cities
for city in cities:  
    
    # Try statement to append calls where value is found 
    # If no city is found due to KeyError: skip and print "city not found"
    try: 
        response = requests.get(query_url +city).json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
               
        # Add one to record counter 
        record = record + 1
        
        # Wait a second in loop
        time.sleep(1.01)
        
    # If no record found "skip" 
    except KeyError:
        print("City not found. Skipping...")
    continue
# Out:
# Retreiving Weather data for below cities
# -------------------------------
# Processing Record 1 | Morehead
# Processing Record 2 | Mataura
# Processing Record 3 | Puerto Ayora
# City not found. Skipping...
# Processing Record 4 | Chui
# Processing Record 5 | Shimoda
# Processing Record 6 | Ushuaia
# Processing Record 7 | Port Hardy
# Processing Record 8 | Cape Town
# Processing Record 9 | Bambous Virieux
# Processing Record 10 | Vaini
# Processing Record 11 | New Norfolk
# Processing Record 12 | Kaitangata
# Processing Record 13 | Ribeira Grande
# Processing Record 14 | Hermanus
# Processing Record 15 | Nanortalik
# Processing Record 16 | Dikson
# City not found. Skipping...
# Processing Record 17 | Atuona
# Processing Record 18 | Ağdaş
# Processing Record 19 | Aksarka
# Processing Record 20 | Touros
# Processing Record 21 | Toora-Khem
# Processing Record 22 | Kahului
# Processing Record 23 | Nikolskoye
# Processing Record 24 | Punta Arenas
# Processing Record 25 | Longyearbyen
# Processing Record 26 | Necochea
# Processing Record 27 | Saint-Philippe
# Processing Record 28 | Bonthe
# Processing Record 29 | Nhulunbuy
# Processing Record 30 | Oistins
# City not found. Skipping...
# Processing Record 31 | Ende
# Processing Record 32 | Beloha
# Processing Record 33 | Khatanga
# Processing Record 34 | Soyo
# Processing Record 35 | Hobart
# Processing Record 36 | Yellowknife
# Processing Record 37 | Toshām
# Processing Record 38 | Koumac
# Processing Record 39 | Albany
# Processing Record 40 | Chardara
# Processing Record 41 | Balkhash
# Processing Record 42 | George Town
# Processing Record 43 | Airai
# Processing Record 44 | Vila
# Processing Record 45 | Tura
# Processing Record 46 | Guerrero Negro
# Processing Record 47 | Upernavik
# Processing Record 48 | Arrondissement de Pontarlier
# Processing Record 49 | Les Cayes
# Processing Record 50 | Rikitea
# Processing Record 51 | San Patricio
# Processing Record 52 | Mīzan Teferī
# Processing Record 53 | Marau
# Processing Record 54 | Thompson
# City not found. Skipping...
# Processing Record 55 | Tateyama
# Processing Record 56 | Saint-François
# Processing Record 57 | Sitka
# City not found. Skipping...
# Processing Record 58 | Port Elizabeth
# Processing Record 59 | Dhrāngadhra
# City not found. Skipping...
# Processing Record 60 | Kerman
# Processing Record 61 | Busselton
# Processing Record 62 | Bathsheba
# Processing Record 63 | Dymytrove
# Processing Record 64 | Hannibal
# Processing Record 65 | Linqiong
# Processing Record 66 | Buta
# Processing Record 67 | Rāvar
# Processing Record 68 | Shingū
# Processing Record 69 | Ankpa
# Processing Record 70 | Hithadhoo
# Processing Record 71 | Malartic
# Processing Record 72 | Ulaangom
# City not found. Skipping...
# Processing Record 73 | São Filipe
# Processing Record 74 | Faya
# Processing Record 75 | Saint Paul Harbor
# Processing Record 76 | Hong Kong
# Processing Record 77 | Hammerfest
# Processing Record 78 | Klichka
# Processing Record 79 | Kaeo
# Processing Record 80 | Tūkrah
# Processing Record 81 | Jiuquan
# Processing Record 82 | Alyangula
# Processing Record 83 | Mayya
# Processing Record 84 | Ponta do Sol
# Processing Record 85 | Cherskiy
# Processing Record 86 | Grindavik
# Processing Record 87 | Saint George
# Processing Record 88 | Blagoyevo
# Processing Record 89 | Gympie
# Processing Record 90 | Belmonte
# Processing Record 91 | Anadyr
# Processing Record 92 | Bluff
# Processing Record 93 | Bredasdorp
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 94 | Mount Gambier
# Processing Record 95 | San Cristobal
# Processing Record 96 | Port Alfred
# Processing Record 97 | Shenjiamen
# Processing Record 98 | Barrow
# Processing Record 99 | Westerland
# Processing Record 100 | Cidreira
# City not found. Skipping...
# Processing Record 101 | Tayirove
# Processing Record 102 | Mvangué
# Processing Record 103 | Avarua
# Processing Record 104 | Talaya
# Processing Record 105 | Lenine
# Processing Record 106 | Kristiansund
# Processing Record 107 | Cosamaloapan
# Processing Record 108 | Kailua
# Processing Record 109 | Carnarvon
# Processing Record 110 | Kabanjahe
# Processing Record 111 | Chokurdakh
# Processing Record 112 | Estrela
# Processing Record 113 | Nizhniy Ingash
# Processing Record 114 | Wenling
# Processing Record 115 | Jamestown
# Processing Record 116 | Kanigoro
# Processing Record 117 | Dudinka
# Processing Record 118 | Arraial do Cabo
# Processing Record 119 | Castro
# Processing Record 120 | Hilo
# Processing Record 121 | Adrar
# Processing Record 122 | Torbay
# Processing Record 123 | Port Blair
# Processing Record 124 | Werda
# City not found. Skipping...
# Processing Record 125 | Saskylakh
# City not found. Skipping...
# Processing Record 126 | Tegul'det
# Processing Record 127 | Trofors
# Processing Record 128 | Qaanaaq
# Processing Record 129 | Esperance
# Processing Record 130 | Zomin
# Processing Record 131 | Chern'
# City not found. Skipping...
# Processing Record 132 | Kanadey
# Processing Record 133 | Kolpashevo
# Processing Record 134 | São Domingos
# Processing Record 135 | Norman Wells
# Processing Record 136 | Chipping Sodbury
# Processing Record 137 | Changping
# Processing Record 138 | Nuevo Progreso
# Processing Record 139 | Tigil'
# Processing Record 140 | Coquimbo
# Processing Record 141 | Kaa-Khem
# Processing Record 142 | San Quintín
# City not found. Skipping...
# Processing Record 143 | Sunbury
# Processing Record 144 | Laguna
# Processing Record 145 | Ixtapa
# Processing Record 146 | Tuktoyaktuk
# City not found. Skipping...
# Processing Record 147 | Torres
# Processing Record 148 | Laas
# Processing Record 149 | Clyde River
# Processing Record 150 | Bāndarban
# Processing Record 151 | Da’an
# Processing Record 152 | Poum
# Processing Record 153 | Beringovskiy
# Processing Record 154 | Belle Fourche
# Processing Record 155 | Port Augusta
# Processing Record 156 | Fort Saint James
# Processing Record 157 | Geraldton
# Processing Record 158 | Praia da Vitória
# Processing Record 159 | Chipinge
# Processing Record 160 | Tiksi
# Processing Record 161 | Urgut
# Processing Record 162 | Troitsko-Pechorsk
# Processing Record 163 | Nadym
# Processing Record 164 | Skrunda
# Processing Record 165 | Boende
# Processing Record 166 | Mitú
# Processing Record 167 | Vilyuysk
# Processing Record 168 | Mahibadhoo
# Processing Record 169 | Amapá
# Processing Record 170 | Ambon City
# Processing Record 171 | Butaritari
# Processing Record 172 | Bull Savanna
# Processing Record 173 | Shimanovsk
# Processing Record 174 | Acajutla
# Processing Record 175 | East London
# Processing Record 176 | Saint-Augustin
# Processing Record 177 | Vagay
# Processing Record 178 | Fukuechō
# Processing Record 179 | Harper
# Processing Record 180 | Waipawa
# Processing Record 181 | Madona
# City not found. Skipping...
# Processing Record 182 | Leningradskiy
# Processing Record 183 | Palmer
# Processing Record 184 | Travesía
# Processing Record 185 | Luanda
# Processing Record 186 | Keti Bandar
# Processing Record 187 | Salyan
# Processing Record 188 | Zhezkazgan
# Processing Record 189 | Biryusinsk
# Processing Record 190 | Severo-Kuril'sk
# Processing Record 191 | Verāval
# Processing Record 192 | Cabo San Lucas
# Processing Record 193 | Katsuura
# Processing Record 194 | Khani
# Processing Record 195 | Cockburn Town
# Processing Record 196 | Yanam
# Processing Record 197 | Hualmay
# City not found. Skipping...
# Processing Record 198 | Faanui
# Processing Record 199 | Nampa
# Processing Record 200 | Santa Cruz del Norte
# Processing Record 201 | Codrington
# Processing Record 202 | Cam Ranh
# Processing Record 203 | Pemangkat
# Processing Record 204 | Santa Rita
# Processing Record 205 | Los Llanos de Aridane
# Processing Record 206 | Port Lincoln
# Processing Record 207 | Birobidzhan
# Processing Record 208 | Ekibastuz
# Processing Record 209 | Lavrentiya
# Processing Record 210 | Anamur
# Processing Record 211 | Santa Isabel
# Processing Record 212 | Miles City
# Processing Record 213 | Steinbach am Taunus
# Processing Record 214 | Moose Factory
# Processing Record 215 | Vuktyl
# Processing Record 216 | Provideniya
# Processing Record 217 | Tamale
# Processing Record 218 | Mahébourg
# Processing Record 219 | Fortuna
# Processing Record 220 | Ahipara
# Processing Record 221 | Hecun
# Processing Record 222 | Monduli
# Processing Record 223 | Houma
# Processing Record 224 | Padang
# Processing Record 225 | Tautira
# Processing Record 226 | Palmas
# Processing Record 227 | Nizhniy Tsasuchey
# Processing Record 228 | Wajima
# Processing Record 229 | Ilulissat
# Processing Record 230 | Olafsvik
# Processing Record 231 | Ginda
# City not found. Skipping...
# Processing Record 232 | Baoding
# Processing Record 233 | Xiongzhou
# Processing Record 234 | Tempio Pausania
# Processing Record 235 | Nokaneng
# Processing Record 236 | Klyuchi
# Processing Record 237 | Te Anau
# Processing Record 238 | Portland
# Processing Record 239 | Vila do Maio
# Processing Record 240 | Zhalantun
# Processing Record 241 | Vila Franca do Campo
# Processing Record 242 | Paamiut
# Processing Record 243 | Agirish
# Processing Record 244 | Balkanabat
# Processing Record 245 | Dubovskoye
# Processing Record 246 | Doha
# Processing Record 247 | Burriana
# Processing Record 248 | Hobyo
# Processing Record 249 | Miguelópolis
# Processing Record 250 | Zhigansk
# Processing Record 251 | La Ronge
# Processing Record 252 | Nouadhibou
# Processing Record 253 | Suicheng
# Processing Record 254 | Havre-St-Pierre
# City not found. Skipping...
# Processing Record 255 | Petropavlovsk-Kamchatskiy
# Processing Record 256 | Nizwá
# Processing Record 257 | Nome
# Processing Record 258 | Oriximiná
# City not found. Skipping...
# Processing Record 259 | Springbok
# Processing Record 260 | Khovd
# Processing Record 261 | Saldanha
# Processing Record 262 | Lilongwe
# Processing Record 263 | Crotone
# City not found. Skipping...
# Processing Record 264 | Ducheng
# Processing Record 265 | Bay City
# Processing Record 266 | Souillac
# Processing Record 267 | Pevek
# Processing Record 268 | Veselí nad Lužnicí
# Processing Record 269 | Bengkulu
# Processing Record 270 | Progreso
# Processing Record 271 | Qaqortoq
# City not found. Skipping...
# Processing Record 272 | Hūn
# Processing Record 273 | Isangel
# Processing Record 274 | Dalbandin
# Processing Record 275 | The Valley
# Processing Record 276 | Lagoa
# Processing Record 277 | Beaverlodge
# Processing Record 278 | Manokwari
# Processing Record 279 | Bethel
# Processing Record 280 | Strand
# Processing Record 281 | Hasaki
# Processing Record 282 | Aklavik
# Processing Record 283 | Malinao
# Processing Record 284 | Tual
# Processing Record 285 | Fairbanks
# Processing Record 286 | Pyn U Lwin
# Processing Record 287 | Mīnāb
# Processing Record 288 | Kinango
# Processing Record 289 | Kapaa
# Processing Record 290 | Phan Thiet
# Processing Record 291 | Dzhebariki-Khaya
# Processing Record 292 | Ustyuzhna
# Processing Record 293 | Bahía Honda
# Processing Record 294 | Knysna
# Processing Record 295 | Taywarah
# Processing Record 296 | Wanaka
# Processing Record 297 | Caravelas
# Processing Record 298 | Mandalgovi
# Processing Record 299 | Laramie
# Processing Record 300 | Lebu
# Processing Record 301 | Marzuq
# Processing Record 302 | Acaraú
# Processing Record 303 | Ţahţā
# Processing Record 304 | Viedma
# Processing Record 305 | Alofi
# Processing Record 306 | Yüksekova
# Processing Record 307 | Comodoro Rivadavia
# Processing Record 308 | Safi
# Processing Record 309 | Butembo
# Processing Record 310 | Urusha
# Processing Record 311 | Auki
# Processing Record 312 | Itarema
# Processing Record 313 | Tasiilaq
# Processing Record 314 | Baracoa
# Processing Record 315 | Kavieng
# Processing Record 316 | Uray
# Processing Record 317 | Salalah
# Processing Record 318 | Hosdurga
# Processing Record 319 | Riachão das Neves
# Processing Record 320 | Athabasca
# Processing Record 321 | Srandakan
# Processing Record 322 | Van Wert
# Processing Record 323 | Las Vegas
# Processing Record 324 | Inhambane
# Processing Record 325 | Fuerte
# Processing Record 326 | Warragul
# Processing Record 327 | Ambilobe
# Processing Record 328 | Scalea
# Processing Record 329 | Parakou
# Processing Record 330 | Bintulu
# Processing Record 331 | Tuatapere
# Processing Record 332 | Dārāb
# Processing Record 333 | Esim
# Processing Record 334 | Caraquet
# Processing Record 335 | Sabha
# City not found. Skipping...
# Processing Record 336 | Liepāja
# Processing Record 337 | Talnakh
# Processing Record 338 | Camocim
# Processing Record 339 | Iqaluit
# Processing Record 340 | Puerto Vallarta
# Processing Record 341 | Northam
# Processing Record 342 | Constitución
# Processing Record 343 | Dongsheng
# City not found. Skipping...
# Processing Record 344 | San Jose
# Processing Record 345 | Lompoc
# Processing Record 346 | Várzea da Palma
# Processing Record 347 | Stari Kuty
# Processing Record 348 | Zhaotong
# Processing Record 349 | Dunedin
# Processing Record 350 | Lázaro Cárdenas
# Processing Record 351 | Korla
# Processing Record 352 | Sisimiut
# Processing Record 353 | Kenai
# Processing Record 354 | Flinders
# Processing Record 355 | Margate
# Processing Record 356 | Hambantota
# Processing Record 357 | Klaksvík
# Processing Record 358 | San Francisco
# Processing Record 359 | Santa Cruz de Barahona
# Processing Record 360 | San Giovanni in Fiore
# Processing Record 361 | Pisco
# Processing Record 362 | Ust'-Ordynskiy
# Processing Record 363 | Ust'-Uda
# Processing Record 364 | Preobrazheniye
# Processing Record 365 | Araouane
# Processing Record 366 | Abéché
# Processing Record 367 | Yakeshi
# Processing Record 368 | Bereda
# Processing Record 369 | Eureka
# Processing Record 370 | Huarmey
# Processing Record 371 | Walvis Bay
# Processing Record 372 | Ust'-Barguzin
# Processing Record 373 | Lüderitz
# Processing Record 374 | Nizhnyaya Tavda
# Processing Record 375 | Humaitá
# Processing Record 376 | Sergiyevsk
# Processing Record 377 | Bamako
# Processing Record 378 | Belaya Gora
# Processing Record 379 | Rocha
# Processing Record 380 | Mpanda
# Processing Record 381 | Mehamn
# Processing Record 382 | Palana
# Processing Record 383 | Manga
# Processing Record 384 | Port Antonio
# Processing Record 385 | Bayangol
# Processing Record 386 | Havelock
# Processing Record 387 | Smoky Lake
# Processing Record 388 | Mago
# City not found. Skipping...
# Processing Record 389 | Ouargaye
# Processing Record 390 | Bibiani
# Processing Record 391 | Mar del Plata
# Processing Record 392 | Obo
# Processing Record 393 | Gamba
# Processing Record 394 | Tayoltita
# Processing Record 395 | Hrubieszów
# Processing Record 396 | São Gabriel da Cachoeira
# Processing Record 397 | Lovozero
# City not found. Skipping...
# Processing Record 398 | Tiarei
# Processing Record 399 | Namtsy
# Processing Record 400 | Redmond
# Processing Record 401 | Kruisfontein
# Processing Record 402 | Muravlenko
# Processing Record 403 | Santa Rosa
# Processing Record 404 | Makakilo City
# Processing Record 405 | Marabba
# Processing Record 406 | Livny
# Processing Record 407 | Yumen
# Processing Record 408 | Penzance
# Processing Record 409 | Gushikawa
# Processing Record 410 | Saint-Pierre
# City not found. Skipping...
# Processing Record 411 | Bratsk
# Processing Record 412 | Bilibino
# Processing Record 413 | Hailar
# Processing Record 414 | Peniche
# Processing Record 415 | Dingle
# Processing Record 416 | Vostok
# City not found. Skipping...
# Processing Record 417 | Willowmore
# Processing Record 418 | Husavik
# City not found. Skipping...
# Processing Record 419 | Oranjemund
# Processing Record 420 | Brejo Santo
# Processing Record 421 | Isla Vista
# Processing Record 422 | Chirongui
# Processing Record 423 | Naze
# Processing Record 424 | Dali
# Processing Record 425 | Prince Rupert
# Processing Record 426 | Hirara
# Processing Record 427 | Chimoio
# Processing Record 428 | Vao
# Processing Record 429 | Vila Velha
# Processing Record 430 | Okhotsk
# Processing Record 431 | Kieta
# Processing Record 432 | Yerbogachën
# Processing Record 433 | Makīnsk
# Processing Record 434 | Meulaboh
# Processing Record 435 | Hoopstad
# Processing Record 436 | Kavaratti
# Processing Record 437 | Kitale
# Processing Record 438 | Barcelos
# Processing Record 439 | Ereymentau
# Processing Record 440 | San Francisco de Becerra
# Processing Record 441 | Kawalu
# Processing Record 442 | Ayan
# Processing Record 443 | Yining
# Processing Record 444 | Najrān
# Processing Record 445 | Santa Catarina de Tepehuanes
# Processing Record 446 | Yaan
# Processing Record 447 | Nampula
# Processing Record 448 | North Bend
# City not found. Skipping...
# Processing Record 449 | Kapoeta
# Processing Record 450 | Sola
# Processing Record 451 | Man
# Processing Record 452 | Port Moresby
# Processing Record 453 | Acapulco de Juárez
# Processing Record 454 | Djibouti
# Processing Record 455 | Pangnirtung
# Processing Record 456 | Balikpapan
# Processing Record 457 | Villa Carlos Paz
# Processing Record 458 | Jardim
# Processing Record 459 | Cayenne
# Processing Record 460 | Srednekolymsk
# Processing Record 461 | Kyshtovka
# Processing Record 462 | St. Pete Beach
# Processing Record 463 | Le Port
# Processing Record 464 | Khuzhir
# Processing Record 465 | Namie
# Processing Record 466 | Masumbwe
# Processing Record 467 | Petauke
# Processing Record 468 | Gijang
# Processing Record 469 | Yeppoon
# Processing Record 470 | Yulara
# Processing Record 471 | Portadown
# Processing Record 472 | Suba
# Processing Record 473 | Ukiah
# Processing Record 474 | Coyhaique
# Processing Record 475 | Grand Gaube
# Processing Record 476 | Ovalle
# Processing Record 477 | Killybegs
# Processing Record 478 | Paciran
# Processing Record 479 | Abhā
# Processing Record 480 | Ostrovnoy
# Processing Record 481 | Jega
# Processing Record 482 | Basco
# Processing Record 483 | Mossamedes
# Processing Record 484 | Conceição do Araguaia
# Processing Record 485 | Alcantarilla
# Processing Record 486 | Envira
# Processing Record 487 | Great Yarmouth
# Processing Record 488 | General Pico
# Processing Record 489 | Diplo
# Processing Record 490 | Moerai
# Processing Record 491 | Havøysund
# Processing Record 492 | Zhirnov
# Processing Record 493 | Kulhudhuffushi
# Processing Record 494 | Narsaq
# Processing Record 495 | Gemeente Wageningen
# Processing Record 496 | Taoudenni
# Processing Record 497 | Itoman
# Processing Record 498 | Wagar
# Processing Record 499 | Goderich
# Processing Record 500 | Rawson
# Processing Record 501 | Sur
# Processing Record 502 | Manggar
# Processing Record 503 | Muscat
# Processing Record 504 | Makat
# City not found. Skipping...
# Processing Record 505 | Makaha
# Processing Record 506 | Kungurtug
# Processing Record 507 | Mabaruma
# Processing Record 508 | Chennai
# Processing Record 509 | Harbour Breton
# Processing Record 510 | Flin Flon
# City not found. Skipping...
# Processing Record 511 | Podor
# Processing Record 512 | Caramay
# Processing Record 513 | Champerico
# Processing Record 514 | Pāsighāt
# City not found. Skipping...
# Processing Record 515 | Tabuk
# Processing Record 516 | Smithers
# Processing Record 517 | Mâncio Lima
# Processing Record 518 | Dobele
# Processing Record 519 | Khandyga
# Processing Record 520 | Maragogi
# Processing Record 521 | Tazmalt
# Processing Record 522 | Kununurra
# Processing Record 523 | College
# Processing Record 524 | Samarinda
# Processing Record 525 | Metro
# Processing Record 526 | Vrede
# Processing Record 527 | Wanning
# Processing Record 528 | Province of Trapani
# Processing Record 529 | Eravur
# Processing Record 530 | Itapora
# Processing Record 531 | Tyukhtet
# Processing Record 532 | Hamilton
# Processing Record 533 | Ancud
# Processing Record 534 | Kysyl-Syr
# Processing Record 535 | Oga
# City not found. Skipping...
# Processing Record 536 | ‘Āhuimanu
# Processing Record 537 | Rūdbār
# Processing Record 538 | Boussé
# Processing Record 539 | Labuhan
# Processing Record 540 | Inírida
# Processing Record 541 | Vaitape
# Processing Record 542 | Muhafazat Lahij
# Processing Record 543 | Yar-Sale
# Processing Record 544 | High Level
# Processing Record 545 | Thunder Bay
# Processing Record 546 | Otse
# Processing Record 547 | Chadiza
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 548 | Simao
# Processing Record 549 | Nishihara
# Processing Record 550 | Mmathubudukwane
# Processing Record 551 | Altamont
# Processing Record 552 | Haines Junction
# Processing Record 553 | Lensk
# Processing Record 554 | Itaituba
# Processing Record 555 | Río Gallegos
# Processing Record 556 | Yuanli
# Processing Record 557 | Savannah Bight
# City not found. Skipping...
# Processing Record 558 | Xingtai
# Processing Record 559 | Asău
# Processing Record 560 | Lorengau
# Processing Record 561 | Mbigou
# Processing Record 562 | Birin
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 563 | Siilinjärvi
# Processing Record 564 | Udachny
# Processing Record 565 | Yarmouth
# City not found. Skipping...
# Processing Record 566 | Buala
# Processing Record 567 | Namwala

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weather_dict = {
    "City": city_name,
    "Cloudiness": cloudiness, 
    "Country": country,
    "Date": date, 
    "Humidity": humidity,
    "Lat": lat, 
    "Lng": lng, 
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}

# Create a data frame the weather dictionary
weather_df = pd.DataFrame(weather_dict)

# Display count of weather data values 
weather_df.count()
# Out:
# City          567
# Cloudiness    567
# Country       567
# Date          567
# Humidity      567
# Lat           567
# Lng           567
# Max Temp      567
# Wind Speed    567
# dtype: int64

# %%
#Make weather df into csv file
weather_df.to_csv("output_data/cities.csv")

#Display the weather_df data
weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Morehead           1      US  1586541671        31  37.27  -87.18
# 1       Mataura           6      NZ  1586542035        95 -46.19  168.86
# 2  Puerto Ayora          20      EC  1586541594        66  -0.74  -90.35
# 3          Chui           6      UY  1586541593        60 -33.70  -53.46
# 4       Shimoda          75      JP  1586542038        70  34.67  138.95
#
#    Max Temp  Wind Speed
# 0     51.01        8.05
# 1     42.01        1.99
# 2     86.00        5.82
# 3     69.33       10.18
# 4     48.20        3.36

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Make a scatter plot to show Latitude Vs. Temperature
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o", s=10)

# Specify labels and title for scatter plot
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
ou
# Save the figure
plt.savefig("Latitude_vs_MaxTemp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Make a scatter plot to show Latitude Vs. Humidity
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o", s=10)

# Specify labels and title for scatter plot
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Make a scatter plot to show Latitude Vs. Cloudiness
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o", s=10)

# Specify labels and title for scatter plot
plt.title("City Latitude vs. Humidity")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Make a scatter plot to show Latitude Vs. Wind Speed 
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o", s=10)

# Specify labels and title for scatter plot
plt.title("City Latitude vs. Wind Speed ")
plt.ylabel("Wind Speed  (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Wind Speed .png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
